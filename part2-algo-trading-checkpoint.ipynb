# %%
import yfinance as yf, pandas as pd, shutil, os, time, glob
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from get_all_tickers import get_tickers as gt
from ta import add_all_ta_features
from ta.utils import dropna

# %% [markdown]
# The library get-all-tickers allows us to compile a list of stock tickers by filtering companies on aspects like market cap or exchange. For this example, we are looking at companies that have a market cap between 150,000 dollar and 10,000,000 dollar(in millions).

# %%
# List of the stocks we are interested in analyzing. At the time of writing this, it narrows the list of stocks down to 44.
# If you have a list of your own you would like to use just create a new list instead of using this, for example: tickers = ["FB", "AMZN", ...] 
tickers = gt.get_tickers_filtered(mktcap_min=150000, mktcap_max=10000000)

# Check that the amount of tickers isn't more than 2000
print("The amount of stocks chosen to observe: " + str(len(tickers)))

# These two lines remove the Stocks folder and then recreate it in order to remove old stocks. Make sure you have created a Stocks Folder the first time you run this.
shutil.rmtree("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Stocks")
os.mkdir("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Stocks")
# Out:
# The amount of stocks chosen to observe: 52

# %%
# Holds the amount of API calls we executed
Amount_of_API_Calls = 0

# This while loop is reponsible for storing the historical data for each ticker in our list. Note that yahoo finance sometimes incurs json.decode errors and because of this we are sleeping for 2
# seconds after each iteration, also if a call fails we are going to try to execute it again.
# Also, do not make more than 2,000 calls per hour or 48,000 calls per day or Yahoo Finance may block your IP. The clause "(Amount_of_API_Calls < 1800)" below will stop the loop from making
# too many calls to the yfinance API.
# Prepare for this loop to take some time. It is pausing for 2 seconds after importing each stock.

# Used to make sure we don't waste too many API calls on one Stock ticker that could be having issues
Stock_Failure = 0
Stocks_Not_Imported = 0

# Used to iterate through our list of tickers
i=0
while (i < len(tickers)) and (Amount_of_API_Calls < 1800):
    try:
        stock = tickers[i]  # Gets the current stock ticker
        temp = yf.Ticker(str(stock))
        Hist_data = temp.history(period="max")  # Tells yfinance what kind of data we want about this stock (In this example, all of the historical data)
        Hist_data.to_csv("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Stocks"+stock+".csv")  # Saves the historical data in csv format for further processing later
        time.sleep(2)  # Pauses the loop for two seconds so we don't cause issues with Yahoo Finance's backend operations
        Amount_of_API_Calls += 1 
        Stock_Failure = 0
        i += 1  # Iteration to the next ticker
        print("Importing stock data:" + str(i))
    except ValueError:
        print("Yahoo Finance Backend Error, Attempting to Fix")  # An error occured on Yahoo Finance's backend. We will attempt to retreive the data again
        if Stock_Failure > 5:  # Move on to the next ticker if the current ticker fails more than 5 times
            i+=1
            Stocks_Not_Imported += 1
        Amount_of_API_Calls += 1
        Stock_Failure += 1
print("The amount of stocks we successfully imported: " + str(i - Stocks_Not_Imported))
# Out:
# Importing stock data:1
# Importing stock data:2
# Importing stock data:3
# Importing stock data:4
# Importing stock data:5
# Importing stock data:6
# Importing stock data:7
# Importing stock data:8
# Importing stock data:9
# Importing stock data:10
# Importing stock data:11
# Importing stock data:12
# Importing stock data:13
# Importing stock data:14
# Importing stock data:15
# Importing stock data:16
# Importing stock data:17
# Importing stock data:18
# Importing stock data:19
# Importing stock data:20
# Importing stock data:21
# Importing stock data:22
# Importing stock data:23
# Importing stock data:24
# Importing stock data:25
# Importing stock data:26
# Importing stock data:27
# Importing stock data:28
# Importing stock data:29
# Importing stock data:30
# Importing stock data:31
# Importing stock data:32
# Importing stock data:33
# Importing stock data:34
# Importing stock data:35
# Importing stock data:36
# Importing stock data:37
# Importing stock data:38
# Importing stock data:39
# Importing stock data:40
# Importing stock data:41
# Importing stock data:42
# Importing stock data:43
# Importing stock data:44
# Importing stock data:45
# Importing stock data:46
# Importing stock data:47
# Importing stock data:48
# Importing stock data:49
# Importing stock data:50
# Importing stock data:51
# Importing stock data:52
# The amount of stocks we successfully imported: 52

# %%
# These two lines remove the Stocks folder and then recreate it in order to remove old stocks. Make sure you have created a Stocks Folder the first time you run this.
shutil.rmtree("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Stocks_Sub")
os.mkdir("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Stocks_Sub")

# Get the Y values
list_files = (glob.glob("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Stocks/*.csv")) # Creates a list of all csv filenames in the stocks folder
for interval in list_files:
    Stock_Name = ((os.path.basename(interval)).split(".csv")[0])
    data = pd.read_csv(interval)
    dropna(data)
    data = add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")
    data = data.iloc[100:]
    close_prices = data['Close'].tolist()
    Five_Day_Obs = []
    thirty_Day_Obs = []
    sixty_Day_Obs = []
    x = 0
    while x < (len(data)):
        if x < (len(data)-5):
            if ((close_prices[x+1] + close_prices[x+2] + close_prices[x+3] + close_prices[x+4] + close_prices[x+5])/5) > close_prices[x]:
                Five_Day_Obs.append(1)
            else:
                Five_Day_Obs.append(0)
        else:
            Five_Day_Obs.append(0)
        x+=1
    y = 0
    while y < (len(data)):
        if y < (len(data)-30):
            ThirtyDayCalc = 0
            y2 = 0
            while y2 < 30:
                ThirtyDayCalc = ThirtyDayCalc + close_prices[y+y2]
                y2 += 1
            if (ThirtyDayCalc/30) > close_prices[y]:
                thirty_Day_Obs.append(1)
            else:
                thirty_Day_Obs.append(0)
        else:
            thirty_Day_Obs.append(0)
        y+=1
    z = 0
    while z < (len(data)):
        if z < (len(data)-60):
            SixtyDayCalc = 0
            z2 = 0
            while z2 < 60:
                SixtyDayCalc = SixtyDayCalc + close_prices[z+z2]
                z2 += 1
            if (SixtyDayCalc/60) > close_prices[z]:
                sixty_Day_Obs.append(1)
            else:
                sixty_Day_Obs.append(0)
        else:
            sixty_Day_Obs.append(0)
        z+=1
    data['Five_Day_Observation_Outcome'] = Five_Day_Obs
    data['Thirty_Day_Observation_Outcome'] = thirty_Day_Obs
    data['Sixty_Day_Observation_Outcome'] = sixty_Day_Obs
    data.to_csv("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Stocks_Sub"+Stock_Name+".csv")
    print("Data for " + Stock_Name + " has been substantiated with technical features.")
# Out:
# C:\Users\DELL-POJ\anaconda3\lib\site-packages\ta\trend.py:608: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# C:\Users\DELL-POJ\anaconda3\lib\site-packages\ta\trend.py:612: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])
# Data for StocksAAPL has been substantiated with technical features.
# Data for StocksABBV has been substantiated with technical features.
# Data for StocksABT has been substantiated with technical features.
# Data for StocksACN has been substantiated with technical features.
# Data for StocksADBE has been substantiated with technical features.
# Data for StocksAMZN has been substantiated with technical features.
# Data for StocksASML has been substantiated with technical features.
# Data for StocksBABA has been substantiated with technical features.
# Data for StocksBAC has been substantiated with technical features.
# Data for StocksCHL has been substantiated with technical features.
# Data for StocksCMCSA has been substantiated with technical features.
# Data for StocksCOST has been substantiated with technical features.
# Data for StocksCRM has been substantiated with technical features.
# C:\Users\DELL-POJ\anaconda3\lib\site-packages\ta\trend.py:636: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i+self._n] = 100 * (self._dip[i]/self._trs[i])
# C:\Users\DELL-POJ\anaconda3\lib\site-packages\ta\trend.py:649: RuntimeWarning: invalid value encountered in double_scalars
#   din[i+self._n] = 100 * (self._din[i]/self._trs[i])
# Data for StocksCSCO has been substantiated with technical features.
# Data for StocksCVX has been substantiated with technical features.
# Data for StocksDIS has been substantiated with technical features.
# Data for StocksFB has been substantiated with technical features.
# Data for StocksGOOG has been substantiated with technical features.
# Data for StocksGOOGL has been substantiated with technical features.
# Data for StocksHD has been substantiated with technical features.
# Data for StocksINTC has been substantiated with technical features.
# C:\Users\DELL-POJ\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\DELL-POJ\anaconda3\lib\site-packages\pandas\core\algorithms.py:1926: RuntimeWarning: invalid value encountered in subtract
#   out_arr[res_indexer] = arr[res_indexer] - arr[lag_indexer]
# Data for StocksJNJ has been substantiated with technical features.
# Data for StocksJPM has been substantiated with technical features.
# Data for StocksKO has been substantiated with technical features.
# Data for StocksMA has been substantiated with technical features.
# Data for StocksMCD has been substantiated with technical features.
# Data for StocksMRK has been substantiated with technical features.
# Data for StocksMSFT has been substantiated with technical features.
# Data for StocksNFLX has been substantiated with technical features.
# Data for StocksNKE has been substantiated with technical features.
# Data for StocksNVDA has been substantiated with technical features.
# Data for StocksNVO has been substantiated with technical features.
# Data for StocksNVS has been substantiated with technical features.
# Data for StocksORCL has been substantiated with technical features.
# Data for StocksPEP has been substantiated with technical features.
# Data for StocksPFE has been substantiated with technical features.
# Data for StocksPG has been substantiated with technical features.
# Data for StocksPYPL has been substantiated with technical features.
# Data for StocksSAP has been substantiated with technical features.
# Data for StocksT has been substantiated with technical features.
# Data for StocksTM has been substantiated with technical features.
# Data for StocksTMO has been substantiated with technical features.
# Data for StocksTSLA has been substantiated with technical features.
# Data for StocksTSM has been substantiated with technical features.
# Data for StocksTV has been substantiated with technical features.
# Data for StocksUL has been substantiated with technical features.
# Data for StocksUN has been substantiated with technical features.
# Data for StocksUNH has been substantiated with technical features.
# Data for StocksV has been substantiated with technical features.
# Data for StocksVZ has been substantiated with technical features.
# Data for StocksWMT has been substantiated with technical features.
# Data for StocksXOM has been substantiated with technical features.

# %%
Hold_Results = []
list_files2 = (glob.glob("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Stocks_Sub/*.csv")) # Creates a list of all csv filenames in the stocks folder
for interval2 in list_files2:
    Stock_Name = ((os.path.basename(interval2)).split(".csv")[0])
    data = pd.read_csv(interval2,index_col=0)
    data = data.replace([np.inf, -np.inf], np.nan)
    data = data.fillna(0)
    dependents = [data["Five_Day_Observation_Outcome"].to_list(), data["Thirty_Day_Observation_Outcome"].to_list(), data["Sixty_Day_Observation_Outcome"].to_list()]
    data = data.drop(['Five_Day_Observation_Outcome', 'Thirty_Day_Observation_Outcome', 'Sixty_Day_Observation_Outcome', 'Date', 'Open', 'High', 'Low', 'Close'], axis = 1)
    scaler = StandardScaler()
    data = scaler.fit_transform(data)  # Standardize our data set
    Hold_Results_Section = []
    p = 0
    for dep in dependents:
        x_train, x_test, y_train, y_test =\
        train_test_split(data, dep, test_size=0.2, random_state=0)
        model = LogisticRegression(solver='liblinear', C=0.05, multi_class='ovr',random_state=0)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)  # To get the predicted values
        conf = confusion_matrix(y_test, y_pred)
        if p == 0:
            Hold_Results.append([Stock_Name, "Five_Day_Observation_Outcome", model.score(x_train, y_train),model.score(x_test, y_test),conf[0,0],conf[0,1],conf[1,0],conf[1,1]])
        if p == 1:
            Hold_Results.append([Stock_Name, "Thirty_Day_Observation_Outcome", model.score(x_train, y_train),model.score(x_test, y_test),conf[0,0],conf[0,1],conf[1,0],conf[1,1]])
        if p == 2:
            Hold_Results.append([Stock_Name, "Sixty_Day_Observation_Outcome", model.score(x_train, y_train),model.score(x_test, y_test),conf[0,0],conf[0,1],conf[1,0],conf[1,1]])
        p+=1
    print("Model complete for " + Stock_Name)
df = pd.DataFrame(Hold_Results, columns=['Stock', 'Observation Period', 'Model Accuracy on Training Data', 'Model Accuracy on Test Data', 'True Positives','False Positives',
'False Negative','True Negative'])
df.to_csv("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Model_Outcome.csv", index = False)
# Out:
# Model complete for Stocks_SubStocksAAPL
# Model complete for Stocks_SubStocksABBV
# Model complete for Stocks_SubStocksABT
# Model complete for Stocks_SubStocksACN
# Model complete for Stocks_SubStocksADBE
# Model complete for Stocks_SubStocksAMZN
# Model complete for Stocks_SubStocksASML
# Model complete for Stocks_SubStocksBABA
# Model complete for Stocks_SubStocksBAC
# Model complete for Stocks_SubStocksCHL
# Model complete for Stocks_SubStocksCMCSA
# Model complete for Stocks_SubStocksCOST
# Model complete for Stocks_SubStocksCRM
# Model complete for Stocks_SubStocksCSCO
# Model complete for Stocks_SubStocksCVX
# Model complete for Stocks_SubStocksDIS
# Model complete for Stocks_SubStocksFB
# Model complete for Stocks_SubStocksGOOG
# Model complete for Stocks_SubStocksGOOGL
# Model complete for Stocks_SubStocksHD
# Model complete for Stocks_SubStocksINTC
# Model complete for Stocks_SubStocksJNJ
# Model complete for Stocks_SubStocksJPM
# Model complete for Stocks_SubStocksKO
# Model complete for Stocks_SubStocksMA
# Model complete for Stocks_SubStocksMCD
# Model complete for Stocks_SubStocksMRK
# Model complete for Stocks_SubStocksMSFT
# Model complete for Stocks_SubStocksNFLX
# Model complete for Stocks_SubStocksNKE
# Model complete for Stocks_SubStocksNVDA
# Model complete for Stocks_SubStocksNVO
# Model complete for Stocks_SubStocksNVS
# Model complete for Stocks_SubStocksORCL
# Model complete for Stocks_SubStocksPEP
# Model complete for Stocks_SubStocksPFE
# Model complete for Stocks_SubStocksPG
# Model complete for Stocks_SubStocksPYPL
# Model complete for Stocks_SubStocksSAP
# Model complete for Stocks_SubStocksT
# Model complete for Stocks_SubStocksTM
# Model complete for Stocks_SubStocksTMO
# Model complete for Stocks_SubStocksTSLA
# Model complete for Stocks_SubStocksTSM
# Model complete for Stocks_SubStocksTV
# Model complete for Stocks_SubStocksUL
# Model complete for Stocks_SubStocksUN
# Model complete for Stocks_SubStocksUNH
# Model complete for Stocks_SubStocksV
# Model complete for Stocks_SubStocksVZ
# Model complete for Stocks_SubStocksWMT
# Model complete for Stocks_SubStocksXOM

# %%
result = pd.read_csv("C:/Users/DELL-POJ/Documents/Iykra/SaidML/Preprocessing Values/Bayesian_Logistic_Regression/Model_Outcome.csv")

# %%
result.head(5)
#jadi dapat dipilih periode kapan yang lebih baik untuk memutuskan sell atau buy dengan melihat kestabilan akurasi model baik pada data testing maupun data training untuk masing-masing stock
# Out:
#                   Stock              Observation Period  \
# 0  Stocks_SubStocksAAPL    Five_Day_Observation_Outcome
# 1  Stocks_SubStocksAAPL  Thirty_Day_Observation_Outcome
# 2  Stocks_SubStocksAAPL   Sixty_Day_Observation_Outcome
# 3  Stocks_SubStocksABBV    Five_Day_Observation_Outcome
# 4  Stocks_SubStocksABBV  Thirty_Day_Observation_Outcome
#
#    Model Accuracy on Training Data  Model Accuracy on Test Data  \
# 0                         0.568130                     0.553481
# 1                         0.614686                     0.605954
# 2                         0.650013                     0.613017
# 3                         0.604524                     0.553425
# 4                         0.665524                     0.676712
#
#    True Positives  False Positives  False Negative  True Negative
# 0             319              616             269            778
# 1             227              608             173            974
# 2             181              591             176           1034
# 3              54              107              56            148
# 4              68               81              37            179

# %% [markdown]
# dapat dikembangkan dan diarahkan pada subkajian yang lain.
